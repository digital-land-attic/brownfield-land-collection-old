# %% [markdown]
# # Brownfield sites collection
#
# Create an index of brownfield land register files collected from Local Planning Authorities.

# %%
# load collection headers into an index

import json
import glob
import re

collection = {"header": {}}

def add(h, category, key):
    collection.setdefault(category, {})
    if category in h:
        collection[category].setdefault(h[category], []).append(key)

p = re.compile("^.*/([\d-]+)/(\w+).json")

for path in glob.glob("collection/headers/*/*.json"):
    date, key = p.match(path).groups()

    h = json.load(open(path))

    for item in ["request-headers", "response-headers"]:
        h.pop(item, None)

    collection["header"][key] = h

    add(h, "dataset", key)
    add(h, "organisation", key)
    add(h, "status", key)
    add(h, "exception", key)

    if "body" in h:
        add(h, "body", key)

# %%
# build index of organisations
import csv
import requests

organisations = {}

def load_organisations(key, fields, url=None, prefix=None):
    if url == None:
        url = 'https://%s.register.gov.uk/records.csv?page-index=1&page-size=5000' % (key)
    if prefix == None:
        prefix = key + ":"
    for row in csv.DictReader(requests.get(url).content.decode('utf-8').splitlines()):
        curie = "%s%s" % (prefix, row[key])
        organisations.setdefault(curie, {})
        for f in fields:
            organisations[curie][f] = row[f] 

load_organisations('local-authority-eng', ['name', 'official-name', 'end-date'])
load_organisations('government-organisation', ['name', 'website', 'end-date'])

# add website and GSS codes for local authorities    
load_organisations("local-authority", ["website", "ons-code"], prefix="", url="https://raw.githubusercontent.com/digital-land/alpha-data/master/local-authorities.csv")

# %%
for status in collection["status"]:
   print(status, len(collection["status"][status]))

print()

for organisation in organisations:  
    print(organisation,
          [collection["header"][key].get("status", "") + collection["header"][key].get("exception", "") 
          for key in collection["organisation"][organisation]],

    )
# Out:
# 200 474
# 404 162
# 403 4
# 500 2
#
# development-corporation:1 ['200', '200']
# development-corporation:2 ['200', '200']
# local-authority-eng:ADU ['200', '200']
# local-authority-eng:ALL ['200', '200']
# local-authority-eng:AMB ['200', '200']
# local-authority-eng:ARU ['200', '200']
# local-authority-eng:ASF ['200', '200']
# local-authority-eng:ASH ['404', '404']
# local-authority-eng:AYL ['200', '200']
# local-authority-eng:BAB ['200', '200']
# local-authority-eng:BAE ['404', '404']
# local-authority-eng:BAI ['404', '404']
# local-authority-eng:BAN ['404', '404']
# local-authority-eng:BAR ['200', '200']
# local-authority-eng:BAS ['200', '200']
# local-authority-eng:BBD ['404', '404']
# local-authority-eng:BDF ['200', '200']
# local-authority-eng:BDG ['200', '200']
# local-authority-eng:BEN ['200', '200']
# local-authority-eng:BEX ['200', '200']
# local-authority-eng:BIR ['200', '200']
# local-authority-eng:BLA ['404', '404']
# local-authority-eng:BMH ['404', '404']
# local-authority-eng:BNE ['200', '200']
# local-authority-eng:BNH ['200', '200']
# local-authority-eng:BNS ['200', '200']
# local-authority-eng:BOL ['200', '200']
# local-authority-eng:BOS ['200', '200']
# local-authority-eng:BOT ['404', '404']
# local-authority-eng:BPL ['200', '200']
# local-authority-eng:BRA ['404', '404']
# local-authority-eng:BRC ['ConnectionError', 'ConnectionError']
# local-authority-eng:BRD ['200', '200']
# local-authority-eng:BRE ['200', '200']
# local-authority-eng:BRM ['200', '200']
# local-authority-eng:BRO ['200', '200']
# local-authority-eng:BRT ['200', '200']
# local-authority-eng:BRW ['200', '200']
# local-authority-eng:BRX ['404', '404']
# local-authority-eng:BRY ['200', '200']
# local-authority-eng:BST ['200', '200']
# local-authority-eng:BUN ['404', '404']
# local-authority-eng:BUR ['200', '200']
# local-authority-eng:CAB ['404', '404']
# local-authority-eng:CAN ['200', '200']
# local-authority-eng:CAR ['200', '200']
# local-authority-eng:CAS ['200', '200']
# local-authority-eng:CAT ['200', '200']
# local-authority-eng:CBF ['404', '404']
# local-authority-eng:CHA ['200', '200']
# local-authority-eng:CHC ['404', '404']
# local-authority-eng:CHE ['200', '200']
# local-authority-eng:CHI ['200', '200']
# local-authority-eng:CHL ['200', '200']
# local-authority-eng:CHN ['404', '404']
# local-authority-eng:CHO ['200', '200']
# local-authority-eng:CHR ['200', '200']
# local-authority-eng:CHS ['404', '404']
# local-authority-eng:CHT ['200', '200']
# local-authority-eng:CHW ['200', '200']
# local-authority-eng:CLD ['200', '200']
# local-authority-eng:CMD ['200', '200']
# local-authority-eng:COL ['200', '200']
# local-authority-eng:CON ['200', '200']
# local-authority-eng:COP ['404', '404']
# local-authority-eng:COR ['200', '200']
# local-authority-eng:COT ['200', '200']
# local-authority-eng:COV ['404', '404']
# local-authority-eng:CRA ['404', '404']
# local-authority-eng:CRW ['200', '200']
# local-authority-eng:CRY ['200', '200']
# local-authority-eng:DAC ['200', '200']
# local-authority-eng:DAL ['200', '200']
# local-authority-eng:DAR ['200', '200']
# local-authority-eng:DAV ['200', '200']
# local-authority-eng:DEB ['200', '200']
# local-authority-eng:DER ['404', '404']
# local-authority-eng:DNC ['404', '404']
# local-authority-eng:DOV ['404', '404']
# local-authority-eng:DUD ['SSLError', 'SSLError']
# local-authority-eng:DUR ['200', '200']
# local-authority-eng:EAL ['200', '200']
# local-authority-eng:EAS ['200', '200']
# local-authority-eng:EAT ['200', '200']
# local-authority-eng:ECA ['200', '200']
# local-authority-eng:EDE ['200', '200']
# local-authority-eng:EDN ['200', '200']
# local-authority-eng:EDO ['404', '404']
# local-authority-eng:EHA ['404', '404']
# local-authority-eng:EHE ['200', '200']
# local-authority-eng:ELI ['200', '200']
# local-authority-eng:ELM ['200', '200']
# local-authority-eng:ENF ['404', '404']
# local-authority-eng:ENO []
# local-authority-eng:EPP ['200', '200']
# local-authority-eng:EPS ['200', '200']
# local-authority-eng:ERE ['200', '200']
# local-authority-eng:ERY ['200', '200']
# local-authority-eng:EST ['200', '200']
# local-authority-eng:EXE ['200', '200']
# local-authority-eng:FAR ['200', '200']
# local-authority-eng:FEN ['200', '200']
# local-authority-eng:FOE ['200', '200']
# local-authority-eng:FOR ['200', '200']
# local-authority-eng:FYL []
# local-authority-eng:GAT ['200', '200']
# local-authority-eng:GED ['200', '200']
# local-authority-eng:GLA []
# local-authority-eng:GLO ['200', '200']
# local-authority-eng:GOS ['200', '200']
# local-authority-eng:GRA ['200', '200']
# local-authority-eng:GRE ['200', '200']
# local-authority-eng:GRT ['200', '200']
# local-authority-eng:GRY ['200', '200']
# local-authority-eng:HAA ['200', '200']
# local-authority-eng:HAE ['200', '200']
# local-authority-eng:HAG ['200', '200']
# local-authority-eng:HAL ['200', '200']
# local-authority-eng:HAO ['404', '404']
# local-authority-eng:HAR ['200', '200']
# local-authority-eng:HAS ['200', '200', '500']
# local-authority-eng:HAT ['200', '200']
# local-authority-eng:HAV ['200', '200']
# local-authority-eng:HCK ['404', '404']
# local-authority-eng:HEF ['200', '200']
# local-authority-eng:HER ['200', '200']
# local-authority-eng:HIG ['200', '200']
# local-authority-eng:HIL ['404', '404']
# local-authority-eng:HIN ['200', '200']
# local-authority-eng:HMF ['200', '200']
# local-authority-eng:HNS ['404', '404']
# local-authority-eng:HOR ['404', '404']
# local-authority-eng:HPL ['200', '200']
# local-authority-eng:HRW ['404', '404']
# local-authority-eng:HRY ['200', '200']
# local-authority-eng:HUN ['200', '200']
# local-authority-eng:HYN ['200', '200']
# local-authority-eng:IOS ['200', '200']
# local-authority-eng:IOW ['200', '200']
# local-authority-eng:IPS ['200', '200']
# local-authority-eng:ISL ['200', '500', '200']
# local-authority-eng:KEC ['200', '200']
# local-authority-eng:KET []
# local-authority-eng:KHL ['200', '200']
# local-authority-eng:KIN ['200', '200']
# local-authority-eng:KIR ['404', '404']
# local-authority-eng:KTT ['200', '200']
# local-authority-eng:KWL ['404', '404']
# local-authority-eng:LAC ['200', '200']
# local-authority-eng:LBH ['200', '200']
# local-authority-eng:LCE ['200', '200']
# local-authority-eng:LDS ['200', '200']
# local-authority-eng:LEE []
# local-authority-eng:LEW ['404', '404']
# local-authority-eng:LIC ['200', '200']
# local-authority-eng:LIF ['404', '404']
# local-authority-eng:LIV ['404', '404']
# local-authority-eng:LND ['404', '404']
# local-authority-eng:LUT ['200', '200']
# local-authority-eng:MAI ['404', '404']
# local-authority-eng:MAL ['200', '200']
# local-authority-eng:MAN ['404', '404']
# local-authority-eng:MAS ['404', '404']
# local-authority-eng:MAV ['404', '404']
# local-authority-eng:MDB ['200', '200']
# local-authority-eng:MDE ['200', '200']
# local-authority-eng:MDW ['200', '200']
# local-authority-eng:MEL ['404', '404']
# local-authority-eng:MEN ['404', '404']
# local-authority-eng:MIK ['200', '200']
# local-authority-eng:MOL ['200', '200']
# local-authority-eng:MRT ['200', '200']
# local-authority-eng:MSS ['200', '200']
# local-authority-eng:MSU []
# local-authority-eng:NBL ['200', '200']
# local-authority-eng:NDE ['404', '404']
# local-authority-eng:NDO ['200', '200']
# local-authority-eng:NEA ['200', '200']
# local-authority-eng:NEC ['200', '200']
# local-authority-eng:NED ['200', '200']
# local-authority-eng:NEL ['404', '404']
# local-authority-eng:NET ['200', '200']
# local-authority-eng:NEW ['200', '200']
# local-authority-eng:NGM ['200', '200']
# local-authority-eng:NHE ['200', '200']
# local-authority-eng:NKE ['200', '200']
# local-authority-eng:NLN ['200', '200']
# local-authority-eng:NNO ['200', '200']
# local-authority-eng:NOR ['200', '200']
# local-authority-eng:NOW ['200', '200']
# local-authority-eng:NSM ['200', '200']
# local-authority-eng:NTY ['SSLError', 'SSLError']
# local-authority-eng:NUN ['200', '200']
# local-authority-eng:NWA []
# local-authority-eng:NWL ['200', '200']
# local-authority-eng:NWM ['404', '404']
# local-authority-eng:OAD ['404', '404']
# local-authority-eng:OLD ['200', '200']
# local-authority-eng:OXO ['200', '200']
# local-authority-eng:PEN ['200', '200']
# local-authority-eng:PLY ['200', '200']
# local-authority-eng:POL ['ConnectionError', 'ConnectionError']
# local-authority-eng:POR ['200', '200']
# local-authority-eng:PRE ['404', '404']
# local-authority-eng:PTE ['200', '200']
# local-authority-eng:PUR ['404', '404']
# local-authority-eng:RCC ['200', '200']
# local-authority-eng:RCH ['200', '200']
# local-authority-eng:RDB ['200', '200']
# local-authority-eng:RDG ['200', '200']
# local-authority-eng:RED ['200', '200']
# local-authority-eng:REI ['200', '200']
# local-authority-eng:RIB ['200', '200']
# local-authority-eng:RIC ['200', '200']
# local-authority-eng:RIH ['404', '404']
# local-authority-eng:ROC ['404', '404']
# local-authority-eng:ROH ['200', '200']
# local-authority-eng:ROS ['200', '200']
# local-authority-eng:ROT ['200', '200']
# local-authority-eng:RUG ['200', '200']
# local-authority-eng:RUH ['200', '', '200']
# local-authority-eng:RUN ['200', '200']
# local-authority-eng:RUS ['404', '404']
# local-authority-eng:RUT ['200', '200']
# local-authority-eng:RYE ['404', '404']
# local-authority-eng:SAL ['404', '404']
# local-authority-eng:SAW ['200', '200']
# local-authority-eng:SBU ['404', '404']
# local-authority-eng:SCA ['200', '200']
# local-authority-eng:SCE ['200', '200']
# local-authority-eng:SDE ['404', '404']
# local-authority-eng:SED []
# local-authority-eng:SEG ['200', '200']
# local-authority-eng:SEL ['200', '200']
# local-authority-eng:SEV ['404', '404']
# local-authority-eng:SFT ['200', '200']
# local-authority-eng:SGC ['200', '200']
# local-authority-eng:SHA ['404', '404']
# local-authority-eng:SHE ['200', '200']
# local-authority-eng:SHF ['200', '200']
# local-authority-eng:SHN ['200', '200']
# local-authority-eng:SHO ['200', '200']
# local-authority-eng:SHR ['200', '200']
# local-authority-eng:SKE ['200', '200']
# local-authority-eng:SKP ['200', '200']
# local-authority-eng:SLA ['200', '200']
# local-authority-eng:SLF ['200', '200']
# local-authority-eng:SLG ['404', '404']
# local-authority-eng:SND ['200', '200']
# local-authority-eng:SNO ['200', '200', '200', '200']
# local-authority-eng:SNR ['200', '200']
# local-authority-eng:SOL ['SSLError', 'SSLError']
# local-authority-eng:SOS ['200', '200']
# local-authority-eng:SOX ['403', '403']
# local-authority-eng:SPE ['200', '200']
# local-authority-eng:SRI ['200', '200']
# local-authority-eng:SSO ['404', '404']
# local-authority-eng:SST ['200', '200']
# local-authority-eng:STA ['404', '404']
# local-authority-eng:STE ['200', '200']
# local-authority-eng:STF ['200', '200']
# local-authority-eng:STH ['200', '200']
# local-authority-eng:STN []
# local-authority-eng:STO ['200', '200']
# local-authority-eng:STR ['200', '200']
# local-authority-eng:STT ['200', '200']
# local-authority-eng:STV ['200', '200']
# local-authority-eng:STY ['200', '200']
# local-authority-eng:SUF ['200', '200']
# local-authority-eng:SUR ['200', '200']
# local-authority-eng:SWD ['200', '200']
# local-authority-eng:SWK ['200', '200']
# local-authority-eng:SWL ['404', '404']
# local-authority-eng:TAM ['200', '200']
# local-authority-eng:TAN ['200', '200']
# local-authority-eng:TAU ['ConnectionError', 'ConnectionError']
# local-authority-eng:TAW ['200', '200']
# local-authority-eng:TEI ['404', '404']
# local-authority-eng:TEN ['200', '200']
# local-authority-eng:TES ['200', '200']
# local-authority-eng:TEW ['404', '404']
# local-authority-eng:TFW ['200', '200']
# local-authority-eng:THA ['200', '200']
# local-authority-eng:THE ['200', '200']
# local-authority-eng:THR ['404', '404']
# local-authority-eng:TOB ['404', '404']
# local-authority-eng:TON ['200', '200']
# local-authority-eng:TOR ['200', '200']
# local-authority-eng:TRF ['200', '200']
# local-authority-eng:TUN ['200', '200']
# local-authority-eng:TWH ['200', '200']
# local-authority-eng:UTT ['404', '404']
# local-authority-eng:VAL ['403', '403']
# local-authority-eng:WAE ['200', '200']
# local-authority-eng:WAT ['200', '200']
# local-authority-eng:WAV ['200', '200']
# local-authority-eng:WAW ['200', '200']
# local-authority-eng:WBK ['200', '200']
# local-authority-eng:WDE ['404', '404']
# local-authority-eng:WDO ['404', '404']
# local-authority-eng:WEA ['200', '200']
# local-authority-eng:WEL []
# local-authority-eng:WEW ['404', '404']
# local-authority-eng:WEY []
# local-authority-eng:WFT ['200', '200']
# local-authority-eng:WGN ['200', '200']
# local-authority-eng:WIL ['200', '200']
# local-authority-eng:WIN ['200', '200']
# local-authority-eng:WKF ['404', '404']
# local-authority-eng:WLA ['200', '200']
# local-authority-eng:WLI ['200', '200']
# local-authority-eng:WLL ['200', '200']
# local-authority-eng:WLV ['200', '200']
# local-authority-eng:WND ['404', '404']
# local-authority-eng:WNM ['200', '200']
# local-authority-eng:WOC ['200', '200']
# local-authority-eng:WOI ['200', '200']
# local-authority-eng:WOK ['200', '200']
# local-authority-eng:WOX ['404', '404']
# local-authority-eng:WRL ['404', '404']
# local-authority-eng:WRT ['404', '404']
# local-authority-eng:WSM ['200', '200']
# local-authority-eng:WSO ['ConnectionError', 'ConnectionError']
# local-authority-eng:WYC ['200', '200']
# local-authority-eng:WYE ['200', '200']
# local-authority:WYO ['200']
# local-authority-eng:WYR ['404', '404']
# local-authority-eng:YOR ['200', '200']
# national-park:1 ['200', '200']
# national-park:10 ['200', '200']
# national-park:2 ['200', '200']
# national-park:3 ['404', '404']
# national-park:4 ['404', '404']
# national-park:5 ['404', '404']
# national-park:6 ['200', '200']
# national-park:7 ['200', '200']
# national-park:8 ['404', '404']
# national-park:9 ['404', '404']
